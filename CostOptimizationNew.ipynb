# %%
# Imports
import pandas as pd
import numpy as np
from sklearn.mixture import GaussianMixture
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.metrics import accuracy_score
from scipy.sparse import hstack


# Load merged dataset
df = pd.read_csv("merged_recipe_price_nodupl.csv")

# Ensure PRICE_USED exists and is filled
if "PRICE_USED" not in df.columns:
    df["PRICE_USED"] = df["PRICE_CURRENT"].fillna(df["PRICE_RETAIL"])
else:
    df["PRICE_USED"] = df["PRICE_USED"].fillna(df["PRICE_CURRENT"]).fillna(df["PRICE_RETAIL"])

# Drop rows without essential info
df = df.dropna(subset=["PRICE_USED", "ingredient", "title"])

# Ensure numeric columns exist and are filled
if "match_score" not in df.columns:
    df["match_score"] = np.nan
df["match_score"] = df["match_score"].fillna(df["match_score"].median())

df["PRODUCT_SIZE"] = pd.to_numeric(df.get("PRODUCT_SIZE", np.nan), errors="coerce")
df["PRODUCT_SIZE"] = df["PRODUCT_SIZE"].fillna(df["PRODUCT_SIZE"].median())

# GMM Clustering
# Text representation: prefer ingredient_clean if present
text_col = "ingredient_clean" if "ingredient_clean" in df.columns else "ingredient"
text_data = df[text_col].astype(str)

vectorizer = CountVectorizer(max_features=400, stop_words="english")
text_features = vectorizer.fit_transform(text_data)

# Numeric features: match_score, PRICE_USED, PRODUCT_SIZE
num_features = df[["match_score", "PRICE_USED", "PRODUCT_SIZE"]].values

# Scale numeric features
scaler = StandardScaler()
num_scaled = scaler.fit_transform(num_features)

# Combine sparse text + dense numeric
X = hstack([text_features, num_scaled])

# GaussianMixture expects dense array
X_dense = X.toarray()

# Fit GMM
n_components = 12 
gmm = GaussianMixture(
    n_components=n_components,
    covariance_type="diag",
    random_state=42
)
gmm.fit(X_dense)

# Assign cluster labels
df["cluster"] = gmm.predict(X_dense)

# LDA classifier for clusters
X_train, X_test, y_train, y_test = train_test_split(
    X_dense,
    df["cluster"],
    test_size=0.3,
    random_state=42,
    stratify=df["cluster"]
)

lda = LDA()
lda.fit(X_train, y_train)
preds_train = lda.predict(X_train)
preds_test = lda.predict(X_test)

print(f"LDA classification accuracy (on testing set): {accuracy_score(y_test, preds_test):.2f}")
print(f"LDA classification accuracy (on training set): {accuracy_score(y_train, preds_train):.2f}")

# Cost Optimization
def optimize_recipe_cost(recipe_name, df, min_match_score=80.0):
    """
    For a given recipe title, select one Walmart product per ingredient.
    - Filters to a single recipe by title
    - Filters out low match_score rows
    - Within each ingredient, keeps the dominant cluster (if >1)
    - Picks the cheapest product (by PRICE_USED) for that ingredient
    Returns (result_dataframe, total_cost).
    """

    # Filter to this recipe
    mask = df["title"].str.lower() == recipe_name.lower()
    recipe_df = df[mask].copy()

    if recipe_df.empty:
        print(f"No recipe found with title: {recipe_name}")
        return None, None

    # Remove rows without usable price
    recipe_df = recipe_df.dropna(subset=["PRICE_USED"])

    # Restrict to good fuzzy matches
    if "match_score" in recipe_df.columns:
        recipe_df = recipe_df[recipe_df["match_score"] >= min_match_score]

    if recipe_df.empty:
        print(f"No usable ingredient matches for recipe: {recipe_name}")
        return None, None

    chosen_rows = []

    # Group by ingredient so we keep one product per ingredient
    for ing, group in recipe_df.groupby("ingredient"):
        # If multiple clusters for this ingredient, keep the dominant cluster
        if "cluster" in group.columns and group["cluster"].nunique() > 1:
            dominant_cluster = group["cluster"].value_counts().idxmax()
            group = group[group["cluster"] == dominant_cluster]

        # Pick the product with minimum package price
        best_idx = group["PRICE_USED"].idxmin()
        best_row = group.loc[best_idx]
        chosen_rows.append(best_row)

    if not chosen_rows:
        print(f"No ingredients could be optimized for recipe: {recipe_name}")
        return None, None

    result = pd.DataFrame(chosen_rows)

    total_cost = result["PRICE_USED"].sum()

    # Clean output table
    cols_out = ["ingredient", "PRODUCT_NAME", "BRAND", "PRICE_USED", "cluster"]
    cols_out = [c for c in cols_out if c in result.columns]
    result = result[cols_out].rename(columns={"PRICE_USED": "Selected_Price"})

    print(f"Optimized cost for '{recipe_name}': ${total_cost:.2f}")
    return result, total_cost

# EXAMPLES
# Example 1
optimized1, total1 = optimize_recipe_cost("Pasta", df)

if optimized1 is not None:
    print("Optimized Ingredient List for Pasta:")
    print(optimized1)

# Example 2
optimized2, total2 = optimize_recipe_cost("Cookies", df)

if optimized2 is not None:
    print("Optimized Ingredient List for Cookies:")
    print(optimized2)

# Example 3
optimized3, total3 = optimize_recipe_cost("Pizza", df)

if optimized3 is not None:
    print("Optimized Ingredient List for Pizza:")
    print(optimized3)
# Out:
# LDA classification accuracy (on testing set): 0.96
# LDA classification accuracy (on training set): 0.96
# Optimized cost for 'Pasta': $47.16
# Optimized Ingredient List for Pasta:
#                        ingredient  \
# 99804              Cheddar cheese
# 98458           Mozzarella cheese
# 98459             Parmesan cheese
# 99806  Wish-Bone Italian dressing
# 98455                       basil
# 99800                black olives
# 98453                      garlic
# 99802                green onions
# 99801                green pepper
# 98454                      olives
# 98451                       penne
# 98456                  red pepper
# 99799                 shell pasta
# 98457                tomato sauce
# 98452            virgin olive oil
#
#                                             PRODUCT_NAME             BRAND  \
# 99804                    cheddar cheese & smoked sausage  long john snacks
# 98458  baker low moisture part skim strings mozzarell...             baker
# 98459       4c 100% natural parmesan/romano cheese, 6 oz          4c foods
# 99806                wish-bone italian dressing, 8 fl oz         wish-bone
# 98455  great value garlic , parmesan & basil seasoned...       great value
# 99800  early california - chopped black ripe olives 4...  early california
# 98453                 eckrich deli sliced garlic bologna           eckrich
# 99802  del monte diced tomatoes green peppers onions,...         del monte
# 99801            cholula green pepper hot sauce, 5 fl oz           cholula
# 98454    partanna castelvetrano whole green olives, 9 oz             asaro
# 98451  birds eye steamfresh veggie pasta penne with c...          birdseye
# 98456  crown prince mildly spiced smoked oysters with...      crown prince
# 99799  la moderna shell pasta has been of preference ...        la moderna
# 98457  annie's organic bernie o's, canned pasta in to...           annie's
# 98452  smart balance buttery spread made with extra v...     smart balance
#
#        Selected_Price  cluster
# 99804            1.79        2
# 98458            7.98        0
# 98459            3.72        3
# 99806            1.92       10
# 98455            2.36        3
# 99800            1.97        3
# 98453            5.12       11
# 99802            1.08        3
# 99801            3.18        3
# 98454            5.76        0
# 98451            3.34        9
# 98456            2.12        3
# 99799            0.48       10
# 98457            2.12       10
# 98452            4.22       10
# Optimized cost for 'Cookies': $27.68
# Optimized Ingredient List for Cookies:
#         ingredient                                       PRODUCT_NAME  \
# 25125  brown sugar  pepperidge farm mini bagels, brown sugar cinna...
# 25124       butter  dove promises peanut butter & dark chocolate c...
# 25128          egg   lenders refrigerated egg bagels 17.1 oz. 6 count
# 25127        flour           great value organic coconut flour, 36 oz
# 25126  white sugar  lillie's q ivory barbeque sauce, tangy white f...
#
#                      BRAND  Selected_Price  cluster
# 25125      pepperidge farm            4.84        8
# 25124       dove chocolate            4.98       11
# 25128             lender's            2.48        7
# 25127  great value organic            9.40        9
# 25126           lillie's q            5.98        8
# Optimized cost for 'Pizza': $84.43
# Optimized Ingredient List for Pizza:
#                ingredient                                       PRODUCT_NAME  \
# 120611  Mozzarella cheese  baker low moisture part skim strings mozzarell...
# 120610    Parmesan cheese       4c 100% natural parmesan/romano cheese, 6 oz
# 120609        dried basil  bumble bee sun-dried tomato & basil seasoned t...
# 120605               eggs  6 count, kinder joy eggs, great for halloween ...
# 24666               flour           great value organic coconut flour, 36 oz
# 120615       green olives    partanna castelvetrano whole green olives, 9 oz
# 120603        ground beef  hormel dried ground formed & sliced dried beef...
# 120612               milk  dove promises variety pack milk and dark choco...
# 120607          mushrooms  bell-view fancy marinated mushrooms in oil, 16...
# 24669                 oil                    carrington farms mct oil powder
# 120604              onion                         bubba's onion bagels, 6 ct
# 120616            oregano  del monte diced tomatoes basil garlic oregano,...
# 120606        pizza sauce  chef boyardee pizza tomato sauce with cheese, ...
# 120608               salt  sabritas salt and lime flavored peanuts, 7 oz bag
# 24667               sugar  applegate natural hickory smoked no sugar uncu...
# 120613      vegetable oil   blue bonnet vegetable oil spread 4 sticks, 16 oz
# 24668           warm milk                              umpqua 1% milk gallon
#
#                       BRAND  Selected_Price  cluster
# 120611                baker            7.98        0
# 120610             4c foods            3.72        3
# 120609           bumble bee            1.08        3
# 120605           kinder joy            7.96        0
# 24666   great value organic            9.40        9
# 120615                asaro            5.76        0
# 120603               hormel            2.92        6
# 120612                 dove            8.98        6
# 120607            bell-view            5.82       10
# 24669      carrington farms           10.94        5
# 120604              bubba’s            2.72        0
# 120616            del monte            0.98        3
# 120606        chef boyardee            1.18       10
# 120608             sabritas            1.88        5
# 24667             applegate            6.24        2
# 120613          blue bonnet            1.63       10
# 24668                umpqua            5.24        6

# %%
# Cluster Analysis

import numpy as np
import pandas as pd
from collections import Counter

def print_top_tokens(text_list, vectorizer, top_k=15):
    """
    Computes most frequent vocabulary terms inside this cluster.
    """
    # Convert text list to sparse matrix
    X = vectorizer.transform(text_list)
    term_counts = np.array(X.sum(axis=0)).flatten()
    vocab = np.array(vectorizer.get_feature_names_out())

    # Sort by count
    idx_sorted = np.argsort(term_counts)[::-1]
    top_terms = vocab[idx_sorted][:top_k]
    return top_terms


def detailed_cluster_report(df, vectorizer, ingredient_col="ingredient_clean", top_n=10):
    """
    Produces summaries for each cluster.
    """

    if ingredient_col not in df.columns:
        ingredient_col = "ingredient"
        
    clusters = sorted(df["cluster"].unique())
    print(f"\n=== Cluster Report ({len(clusters)} clusters) ===\n")

    for c in clusters:
        sub = df[df["cluster"] == c]
        print(f"\n============================================================")
        print(f"CLUSTER {c} — {len(sub)} rows")
        print("============================================================\n")

        # Ingredients
        print("Top Ingredients:")
        top_ing = (
            sub[ingredient_col]
            .value_counts()
            .head(top_n)
            .index
            .tolist()
        )
        for ing in top_ing:
            print("  •", ing)
        print()

        # Product Names
        if "PRODUCT_NAME" in sub.columns:
            print("Top Product Names:")
            top_products = (
                sub["PRODUCT_NAME"]
                .value_counts()
                .head(top_n)
                .index
                .tolist()
            )
            for p in top_products:
                print("  •", p)
            print()

        # Brands
        if "BRAND" in sub.columns:
            print("Top Brands:")
            top_brands = (
                sub["BRAND"]
                .value_counts()
                .head(top_n)
                .index
                .tolist()
            )
            for b in top_brands:
                print("  •", b)
            print()

        # Category/Subcategory
        if "CATEGORY" in sub.columns:
            print("Category Breakdown:")
            top_cat = (
                sub["CATEGORY"]
                .value_counts()
                .head(top_n)
                .index
                .tolist()
            )
            for c2 in top_cat:
                print("  •", c2)
            print()

        if "SUBCATEGORY" in sub.columns:
            print("Subcategory Breakdown:")
            top_subcat = (
                sub["SUBCATEGORY"]
                .value_counts()
                .head(top_n)
                .index
                .tolist()
            )
            for sc in top_subcat:
                print("  •", sc)
            print()

        # Price
        if "PRICE_USED" in sub.columns:
            print("Price Statistics:")
            print(f"  Mean Price: ${sub['PRICE_USED'].mean():.2f}")
            print(f"  Median:     ${sub['PRICE_USED'].median():.2f}")
            print(f"  Min:        ${sub['PRICE_USED'].min():.2f}")
            print(f"  Max:        ${sub['PRICE_USED'].max():.2f}")
            print()

        # Tokens
        print("Top Text Tokens:")
        top_tokens = print_top_tokens(sub[ingredient_col].astype(str).tolist(), vectorizer, top_k=15)
        print("  ", ", ".join(top_tokens))
        print("\n\n")

# Generate report:
detailed_cluster_report(df, vectorizer, ingredient_col="ingredient_clean", top_n=10)
# Out:
# === Detailed Cluster Report (12 clusters) ===
#
#
# ============================================================
# CLUSTER 0 — 21112 rows
# ============================================================
#
# Top Ingredients:
#   • onion
#   • eggs
#   • nuts
#   • cream cheese
#   • pecans
#   • lemon juice
#   • raisins
#   • bacon
#   • mustard
#   • cream of mushroom soup
#
# Top Product Names:
#   • bubba's onion bagels, 6 ct
#   • 6 count, kinder joy eggs, great for halloween treats, 4.2 oz
#   • ziyad castania extra mixed nuts 300 gm
#   • great value cinnamon rolls with cream cheese icing, 8 count
#   • diamond of californiachopped pecans, 8oz
#   • hawaiian punch lemon berry squeeze, juice drink, 1 gal bottle
#   • gary's quicksteak chicken
#   • puck puck cream
#   • pepperidge farm swirl 100% whole wheat cinnamon with raisins breakfast bread, 16 oz loaf
#   • al fresco original uncured chicken bacon, 3 oz.
#
# Top Brands:
#   • bubba’s
#   • kinder joy
#   • great value
#   • castania
#   • diamond
#   • hawaiian punch
#   • gary's quicksteak
#   • puck
#   • al fresco
#   • pepperidge farm
#
# Category Breakdown:
#   • breakfast breads
#   • chocolate
#   • baking nuts & seeds
#   • bacon, hot dogs, sausage
#   • canned goods
#   • biscuits, cookies, doughs
#   • beverage deals
#   • condiments
#   • frozen meat & seafood
#   • international foods
#
# Subcategory Breakdown:
#   • shop all
#   • bagels
#   • english muffins
#   • cereal bars
#   • beef & lamb
#   • coffee
#   • fresh vegetables
#   • bakery cookies
#   • imported beer
#   • pork
#
# Price Statistics:
#   Mean Price: $4.75
#   Median:     $4.48
#   Min:        $0.84
#   Max:        $13.48
#
# Top Text Tokens:
#    onion, eggs, cream, cheese, chicken, soup, lemon, nuts, pecans, juice, mustard, mushroom, bacon, raisins, broth
#
#
#
#
# ============================================================
# CLUSTER 1 — 273 rows
# ============================================================
#
# Top Ingredients:
#   • maraschino cherries
#   • cherries
#   • candied cherries
#   • red cherries
#   • green cherries
#   • dark sweet pitted cherries
#   • tart cherries
#   • frozen cherries
#   • red tart cherries
#   • dark sweet cherries
#
# Top Product Names:
#   • great value maraschino cherries, 16 oz
#   • del monte canned dark sweet pitted cherries, heavy syrup, 15 oz can
#   • sunripe candied green cherries, 8 oz.
#   • oregon specialty fruit red tart cherries in water, 14.5 oz can
#   • great value dark sweet cherries, frozen, pitted, frozen, 16 oz
#
# Top Brands:
#   • great value
#   • del monte
#   • sunripe
#   • oregon fruit products
#
# Category Breakdown:
#   • canned goods
#   • healthy snacks
#   • frozen produce
#
# Subcategory Breakdown:
#   • shop all
#
# Price Statistics:
#   Mean Price: $3.33
#   Median:     $3.28
#   Min:        $2.98
#   Max:        $4.47
#
# Top Text Tokens:
#    cherries, maraschino, candied, red, green, sweet, dark, frozen, cracker, extra, dried, dry, egg, eggplant, cottage
#
#
#
#
# ============================================================
# CLUSTER 2 — 12559 rows
# ============================================================
#
# Top Ingredients:
#   • sugar
#   • cheddar cheese
#   • powdered sugar
#   • cocoa
#   • cornstarch
#   • peanut butter
#   • honey
#   • allpurpose
#   • ground cinnamon
#   • semisweet chocolate chips
#
# Top Product Names:
#   • applegate natural hickory smoked no sugar uncured bacon, 9oz (frozen)
#   • cheddar cheese & smoked sausage
#   • kool-aid sugar-sweetened cherry artificially flavored powdered soft drink mix, 19 oz canister
#   • lily's 70% cocoa extra dark chocolate bar, 2.8 oz
#   • great value corn starch, 16 oz
#   • dove promises peanut butter & dark chocolate candy - 7.61 oz bag
#   • johnsonville brown sugar & honey breakfast sausage links, 12 oz
#   • goldee's all purpose rub
#   • el sembrador coconut, 14 oz
#   • don francisco's coffee 100% arabica cinnamon hazelnut, medium roast, ground coffee, 12 oz
#
# Top Brands:
#   • applegate
#   • long john snacks
#   • great value
#   • kool-aid
#   • lily's sweets
#   • dove chocolate
#   • johnsonville
#   • goldee's
#   • el sembrador
#   • don francisco's coffee
#
# Category Breakdown:
#   • bacon, hot dogs, sausage
#   • better for you
#   • drink mixes
#   • baking soda & starch
#   • herbs, spices & seasonings
#   • chocolate
#   • baking nuts & seeds
#   • breakfast beverages
#   • condiments
#   • beverage deals
#
# Subcategory Breakdown:
#   • shop all
#   • coffee
#   • beef & lamb
#   • fresh fruits
#   • fresh vegetables
#   • rye & sourdough bread
#   • cereal bars
#   • baguettes, loaves & breadsticks
#   • artisan breads
#   • pork
#
# Price Statistics:
#   Mean Price: $4.77
#   Median:     $6.24
#   Min:        $0.30
#   Max:        $44.98
#
# Top Text Tokens:
#    sugar, cheese, cheddar, powdered, cocoa, cornstarch, butter, peanut, ground, chocolate, semisweet, honey, allpurpose, coconut, ginger
#
#
#
#
# ============================================================
# CLUSTER 3 — 21438 rows
# ============================================================
#
# Top Ingredients:
#   • pepper
#   • celery
#   • onions
#   • green pepper
#   • parmesan cheese
#   • parsley
#   • coconut
#   • paprika
#   • oregano
#   • green onions
#
# Top Product Names:
#   • jack links cold crafted hard salami & pepper jack cheese linkwich 1.5oz
#   • del monte diced tomatoes green peppers onions, 14.5 oz can
#   • del monte stewed tomatoes onions celery peppers, 14.5 oz can
#   • cholula green pepper hot sauce, 5 fl oz
#   • parsley fresh cut .75oz
#   • 4c 100% natural parmesan/romano cheese, 6 oz
#   • birds eye coconut, frozen coconut flakes, 6 oz
#   • great value paprika, 2.5 oz
#   • del monte diced tomatoes basil garlic oregano, 14.5 oz can
#   • badia kosher ground cloves, 1.75 oz
#
# Top Brands:
#   • del monte
#   • great value
#   • jack link's
#   • badia
#   • 4c foods
#   • cholula
#   • produce unbranded
#   • rocket farms
#   • birdseye
#   • goya
#
# Category Breakdown:
#   • canned goods
#   • bacon, hot dogs, sausage
#   • condiments
#   • herbs, spices & seasonings
#   • fresh food
#   • cheese
#   • chips
#   • easy to make
#   • baking nuts & seeds
#   • cut fruits & vegetables
#
# Subcategory Breakdown:
#   • shop all
#   • fresh vegetables
#   • bbq ribs
#   • fresh fruits
#   • cocoa
#   • cake and cupcakes
#   • grilled shrimp kabobs
#   • croissants
#   • fresh bakery breads
#   • brownies & dessert bars
#
# Price Statistics:
#   Mean Price: $2.10
#   Median:     $1.88
#   Min:        $0.20
#   Max:        $18.48
#
# Top Text Tokens:
#    pepper, green, celery, onions, cheese, parsley, parmesan, black, chili, coconut, powder, cream, red, pudding, peppers
#
#
#
#
# ============================================================
# CLUSTER 4 — 26 rows
# ============================================================
#
# Top Ingredients:
#   • citron
#   • triple sec
#   • orange liqueur
#   • red spanish
#   • estates seven oaks cabernet
#   • estates riverstone
#   • peppermint schnapps
#   • rye whiskey
#   • irish whiskey
#   • sparkling wine
#
# Top Product Names:
#   • absolut citron flavored vodka 750ml bottle
#   • dekuyper triple sec liqueur, 750 ml
#   • jim beam orange liqueur with kentucky straight bourbon whiskey 750 ml
#   • locations spanish red blend red wine 750ml
#   • j. lohr estates seven oaks cabernet sauvignon, california red wine, 750 ml bottle
#   • j. lohr estates riverstone chardonnay, california white wine, 750 ml bottle
#   • rumple minze peppermint schnapps, 750 ml, 50% abv
#   • bulleit 95 rye whiskey 750 ml 95 proof
#   • bushmills irish whiskey, 750 ml
#   • andre champagne blush sparkling wine 750ml
#
# Top Brands:
#   • absolut
#   • dekuyper
#   • jim beam
#   • j lohr vinery & wines
#   • locations
#   • rumple minze
#   • bulleit
#   • bushmills
#   • andre
#   • farm fresh wine company
#
# Category Breakdown:
#   • spirits
#   • wine
#
# Subcategory Breakdown:
#   • vodka
#   • cocktails
#   • whiskey
#   • red wine
#   • white wine
#   • blush wine
#   • liqueurs & cordials
#
# Price Statistics:
#   Mean Price: $14.60
#   Median:     $13.98
#   Min:        $7.98
#   Max:        $27.48
#
# Top Text Tokens:
#    orange, wine, red, fresh, peach, rye, zucchini, elbow, dill, doritos, dressing, dried, dry, egg, eggplant
#
#
#
#
# ============================================================
# CLUSTER 5 — 13647 rows
# ============================================================
#
# Top Ingredients:
#   • salt
#   • vanilla
#   • oil
#   • chicken
#   • walnuts
#   • cheese
#   • pork
#   • pork chops
#   • sharp cheese
#   • meal
#
# Top Product Names:
#   • sabritas salt and lime flavored peanuts, 7 oz bag
#   • cafe agave cafe agave cold brew vanilla cinn 4pk
#   • carrington farms mct oil powder
#   • aidells chicken & apple smoked chicken sausage links, 12 oz, 4 ct
#   • diamond of california chopped walnuts, 8 oz
#   • eckrich cheese franks, 12 oz
#   • aidells cajun style andouille smoked pork sausage links, 12 oz, 4 count
#   • boneless pork sirloin chops, 1.0 - 2.1 lb
#   • cabot extra sharp cheddar cheese, 2 lbs
#   • slimfast advanced nutrition vanilla cream meal replacement smoothie mix, 12 servings
#
# Top Brands:
#   • sabritas
#   • cafe agave
#   • carrington farms
#   • aidells
#   • diamond
#   • eckrich
#   • fresh pork
#   • cabot creamery
#   • slimfast
#   • great value
#
# Category Breakdown:
#   • baking nuts & seeds
#   • beer
#   • bacon, hot dogs, sausage
#   • baking soda & starch
#   • cheese
#   • fresh food
#   • canned goods
#   • drink mixes
#   • herbs, spices & seasonings
#   • frozen meat & seafood
#
# Subcategory Breakdown:
#   • flavored beer & hard seltzers
#   • shop all
#   • pork
#   • chicken
#   • institutional food
#   • seafood
#   • blush wine
#   • cake and cupcakes
#   • bbq ribs
#   • specialty wine
#
# Price Statistics:
#   Mean Price: $5.35
#   Median:     $1.88
#   Min:        $0.54
#   Max:        $18.53
#
# Top Text Tokens:
#    salt, vanilla, oil, chicken, cheese, walnuts, pork, chops, sharp, yogurt, meal, seasoning, wine, pickling, avocados
#
#
#
#
# ============================================================
# CLUSTER 6 — 9467 rows
# ============================================================
#
# Top Ingredients:
#   • milk
#   • margarine
#   • ground beef
#   • rice
#   • chocolate chips
#   • corn
#   • broccoli
#   • ground chuck
#   • barbecue sauce
#   • frozen broccoli
#
# Top Product Names:
#   • dove promises variety pack milk and dark chocolate candy - 15.8 oz bag
#   • land o lakes margarine, 1 lb
#   • hormel dried ground formed & sliced dried beef jar, 2.5 oz
#   • ito en oi ocha unsweetened green tea with roasted rice, 16.9 fl oz, 1 count
#   • oakrun farms belgian waffles with chocolate chips for breakfast and snacking, 2.4 oz, 6 count
#   • argo gluten free pure corn starch, 16 oz jar
#   • campbell's slow kettle style broccoli cheddar soup with a crunch, 7 ounce microwavable cup
#   • all natural* 80% lean/20% fat ground beef chuck roll, 1 lb
#   • absolutely wild hot barbecue sauce, 19.4 oz
#   • birds eye steamfresh broccoli florets, frozen, 10.8 oz
#
# Top Brands:
#   • dove
#   • land o'lakes
#   • hormel
#   • ito en
#   • oakrun farm bakery
#   • argo
#   • campbell's
#   • fresh ground beef
#   • birdseye
#   • absolutely wild
#
# Category Breakdown:
#   • better for you
#   • butter & margarine
#   • canned goods
#   • breakfast beverages
#   • condiments
#   • breakfast breads
#   • fresh food
#   • baking soda & starch
#   • chips
#   • bacon, hot dogs, sausage
#
# Subcategory Breakdown:
#   • shop all
#   • tea
#   • croissants
#   • beef & lamb
#   • fresh vegetables
#   • coffee
#   • plant-base alternatives
#   • cocoa
#   • pork
#   • institutional food
#
# Price Statistics:
#   Mean Price: $5.54
#   Median:     $3.93
#   Min:        $0.64
#   Max:        $21.76
#
# Top Text Tokens:
#    milk, margarine, ground, beef, rice, chips, chocolate, corn, broccoli, sauce, frozen, chuck, hot, barbecue, spinach
#
#
#
#
# ============================================================
# CLUSTER 7 — 10598 rows
# ============================================================
#
# Top Ingredients:
#   • egg
#   • baking soda
#   • mayonnaise
#   • vinegar
#   • soda
#   • bread crumbs
#   • buttermilk
#   • apples
#   • hamburger
#   • bread
#
# Top Product Names:
#   • arm & hammer baking soda, 1 lb.
#   • lenders refrigerated egg bagels 17.1 oz. 6 count
#   • mother beverage: beverage cider vinegar blood orange, 12 fo
#   • best foods gluten-free mayonnaise, 48 fl oz
#   • 4c foods 4c bread crumbs, 46 oz
#   • great value buttermilk biscuits, 10 count, 4 pack
#   • rhodes bake-n-serv, white bread dough, 5 ct
#   • dole fruit bowls apples & creme parfait, 4.3 oz fruit parfait, 4 cups
#   • best maid hamburger slices, 46 fl oz
#   • bob evans 100% liquid egg whites, 32 oz
#
# Top Brands:
#   • arm & hammer
#   • lender's
#   • poppi
#   • best foods
#   • great value
#   • betty crocker
#   • 4c foods
#   • rhodes
#   • dole
#   • best maid
#
# Category Breakdown:
#   • baking soda & starch
#   • breakfast breads
#   • condiments
#   • canned goods
#   • beverage deals
#   • biscuits, cookies, doughs
#   • easy to make
#   • herbs, spices & seasonings
#   • eggs
#   • cooking oils & vinegars
#
# Subcategory Breakdown:
#   • shop all
#   • bagels
#   • croissants
#   • institutional food
#   • fresh fruits
#   • juice
#   • cake and cupcakes
#   • flavored beer & hard seltzers
#   • coffee
#   • toast
#
# Price Statistics:
#   Mean Price: $3.57
#   Median:     $2.48
#   Min:        $0.30
#   Max:        $19.68
#
# Top Text Tokens:
#    soda, egg, vinegar, baking, mayonnaise, bread, cake, crumbs, buttermilk, mix, white, apples, syrup, hamburger, whites
#
#
#
#
# ============================================================
# CLUSTER 8 — 4564 rows
# ============================================================
#
# Top Ingredients:
#   • brown sugar
#   • cinnamon
#   • potatoes
#   • confectioners sugar
#   • white sugar
#   • light brown sugar
#   • red
#   • red potatoes
#   • frozen hash brown potatoes
#   • white
#
# Top Product Names:
#   • pepperidge farm mini bagels, brown sugar cinnamon, 17 oz. bag, 12-pack
#   • great value cinnamon rolls with cream cheese icing, 8 count
#   • bruce's yams cut sweet potatoes in syrup, canned vegetables, 29 oz
#   • great value confectioners powdered sugar, 32 oz
#   • lillie's q ivory barbeque sauce, tangy white flavor, zero sugar, 17 oz
#   • great value light brown sugar, 32 oz
#   • carolina pride red hot dogs family pack, 48 oz.
#   • just crack an egg southwest style scramble breakfast bowl kit with chorizo, monterey jack cheese, potatoes, tomatoes, green and red bell peppers, jalapeno peppers and onions, 3 oz. cup
#   • ore-ida diced hash brown frozen potatoes, 32 oz bag
#   • white claw mango hard seltzer 24oz
#
# Top Brands:
#   • great value
#   • pepperidge farm
#   • bruce's
#   • lillie's q
#   • ore-ida
#   • carolina pride
#   • just crack an egg
#   • mike’s
#   • badia
#   • produce unbranded
#
# Category Breakdown:
#   • breakfast breads
#   • biscuits, cookies, doughs
#   • canned goods
#   • great value beverages
#   • condiments
#   • frozen breakfast
#   • bacon, hot dogs, sausage
#   • eggs
#   • beer
#   • herbs, spices & seasonings
#
# Subcategory Breakdown:
#   • bagels
#   • shop all
#   • flavored beer & hard seltzers
#   • fresh vegetables
#   • coffee
#   • red wine
#   • plant-base alternatives
#   • fresh fruits
#   • seafood
#
# Price Statistics:
#   Mean Price: $3.30
#   Median:     $1.98
#   Min:        $1.28
#   Max:        $21.64
#
# Top Text Tokens:
#    sugar, brown, cinnamon, potatoes, white, confectioners, light, red, frozen, hash, dark, powdered, vanilla, dry, egg
#
#
#
#
# ============================================================
# CLUSTER 9 — 6361 rows
# ============================================================
#
# Top Ingredients:
#   • flour
#   • cashews
#   • bourbon
#   • shallots
#   • bran
#   • beets
#   • alum
#   • breadcrumbs
#   • apricots
#   • prunes
#
# Top Product Names:
#   • great value organic coconut flour, 36 oz
#   • emerald nuts, cashews & almonds with dried cranberries, 100 calorie packs, 10 ct, 6.9 oz
#   • bush's bourbon & brown sugar grillin' beans, plant-based protein, canned beans, 22 oz
#   • joseph's flax, oat bran & whole wheat lavash bread, 4 count, 9 oz
#   • shallots, 3 oz
#   • aunt millie's english muffins, 100% whole wheat, 6 ct., 12 oz.
#   • aunt nellie's sweet & sour harvard beets 15.5 oz jar
#   • carrington farms keto breadcrumbs, italian flavor 7.0 oz
#   • great value alum, 3.5 oz
#   • (4 cans) del monte bartlett pears, no sugar added, canned fruit, 14.5 oz
#
# Top Brands:
#   • great value organic
#   • great value
#   • bush's
#   • produce unbranded
#   • del monte
#   • aunt millie's
#   • freshness guaranteed
#   • emerald
#   • birdseye
#   • joseph's
#
# Category Breakdown:
#   • baking soda & starch
#   • canned goods
#   • fresh food
#   • condiments
#   • herbs, spices & seasonings
#   • bacon, hot dogs, sausage
#   • beer
#   • healthy snacks
#   • breakfast breads
#   • cheese
#
# Subcategory Breakdown:
#   • shop all
#   • seafood
#   • fresh vegetables
#   • flavored beer & hard seltzers
#   • english muffins
#   • flatbreads
#   • domestic beer
#   • fresh fruits
#   • brownies & dessert bars
#   • coffee mugs
#
# Price Statistics:
#   Mean Price: $8.26
#   Median:     $9.40
#   Min:        $0.48
#   Max:        $51.48
#
# Top Text Tokens:
#    flour, substitute, sugar, tortilla, elbow, dates, dill, doritos, dressing, dried, dry, egg, eggplant, eggs, zucchini
#
#
#
#
# ============================================================
# CLUSTER 10 — 19530 rows
# ============================================================
#
# Top Ingredients:
#   • baking powder
#   • sour cream
#   • tomatoes
#   • shortening
#   • worcestershire sauce
#   • carrots
#   • mushrooms
#   • nutmeg
#   • vegetable oil
#   • tomato sauce
#
# Top Product Names:
#   • clabber girl double acting baking powder, 22 oz
#   • cape cod potato chips, sour cream and onion kettle chips, 7.5 oz
#   • bella sun luci julienne cut sun dried with italian herbs tomatoes, 8.5 oz
#   • crisco all vegetable shortening, 16 oz can
#   • heinz worcestershire sauce, 18 fl oz bottle
#   • badia nutmeg ground, bottle
#   • annie's organic bernie o's, canned pasta in tomato & cheese sauce, 15 oz.
#   • del monte peas & carrots, canned vegetables, 14.5 oz can
#   • bell-view fancy marinated mushrooms in oil, 16.0 fl oz
#   • blue bonnet vegetable oil spread 4 sticks, 16 oz
#
# Top Brands:
#   • clabber girl
#   • cape cod
#   • bella sun luci
#   • del monte
#   • annie's
#   • crisco
#   • heinz
#   • great value
#   • badia
#   • bell-view
#
# Category Breakdown:
#   • canned goods
#   • condiments
#   • baking soda & starch
#   • chips
#   • herbs, spices & seasonings
#   • cheese
#   • butter & margarine
#   • easy to make
#   • oils & shortening
#   • frozen desserts
#
# Subcategory Breakdown:
#   • shop all
#   • fresh vegetables
#   • toast
#   • camping food
#   • domestic beer
#   • fresh fruits
#   • tortillas, pitas & wraps
#   • institutional food
#   • tea
#   • cocoa
#
# Price Statistics:
#   Mean Price: $3.42
#   Median:     $3.44
#   Min:        $0.42
#   Max:        $17.98
#
# Top Text Tokens:
#    powder, sauce, cream, baking, oil, sour, tomatoes, tomato, shortening, cheese, worcestershire, garlic, mushrooms, carrots, nutmeg
#
#
#
#
# ============================================================
# CLUSTER 11 — 9986 rows
# ============================================================
#
# Top Ingredients:
#   • butter
#   • garlic
#   • pineapple
#   • orange juice
#   • ginger
#   • beans
#   • shrimp
#   • pineapple juice
#   • beef
#   • chocolate
#
# Top Product Names:
#   • dove promises peanut butter & dark chocolate candy - 7.61 oz bag
#   • natural light naturdays pineapple lemonade beer, 30 pack 12 fl. oz. cans, 4.2% abv
#   • eckrich deli sliced garlic bologna
#   • hawaiian punch orange ocean, juice drink, 1 gal bottle
#   • press premium hard seltzer variety pack with blackberry hibiscus, pomegranate ginger, lime lemongrass and grapefruit cardamom, 12 pk 12 fl oz cans, 4.0% abv
#   • landmark coffee beans hazelnut creme, 32 oz
#   • bd shrimp dried
#   • del monte pineapple chunks in 100% juice, canned fruit, 20 oz can
#   • amb nc beef hd lrg
#   • parle hide & seek chocolate chip cookies, 6 - 2.91 oz packs
#
# Top Brands:
#   • dove chocolate
#   • natural light
#   • eckrich
#   • hawaiian punch
#   • press
#   • del monte
#   • landmark coffee
#   • badia
#   • ambassador
#   • great value
#
# Category Breakdown:
#   • better for you
#   • beer
#   • bacon, hot dogs, sausage
#   • canned goods
#   • beverage deals
#   • breakfast beverages
#   • fresh food
#   • baking soda & starch
#   • condiments
#   • frozen desserts
#
# Subcategory Breakdown:
#   • domestic beer
#   • shop all
#   • flavored beer & hard seltzers
#   • coffee
#   • beef & lamb
#   • fresh vegetables
#   • brandy & cognac
#   • fresh fruits
#   • seafood
#   • chicken
#
# Price Statistics:
#   Mean Price: $7.02
#   Median:     $4.98
#   Min:        $0.80
#   Max:        $54.44
#
# Top Text Tokens:
#    butter, pineapple, garlic, juice, orange, beans, beef, ginger, shrimp, chocolate, apple, meat, frozen, lemonade, crab
